# %%
import matplotlib.pyplot as plt

# DATASET SIZE : 4.52 MB

# Encryption time
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [1.8762, 0.4892, 2.4074, 0.5216, 1.8379]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Encryption Time in seconds", ylabel="ENCRYPTION TIME");

# Decryption time
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [1.9161, 0.1990, 12.70, 0.4092, 1.8724]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Decryption Time in seconds", ylabel="DECRYPTION TIME");

# Memory usage
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [11.30, 9.20, 12.80, 17.00, 67.30]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Memory Usage in percentage", ylabel="MEMORY USAGE");

# CPU Usage
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [77.60, 84.20, 88.00, 94.70, 20.00]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="CPU Usage in percentage", ylabel="CPU USAGE");

# %%
import matplotlib.pyplot as plt

# DATASET SIZE : 25 MB

# Encryption time
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [115.2802, 6.6622, 94.507, 18.8782, 119.5780]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Encryption Time in seconds", ylabel="ENCRYPTION TIME");

# Decryption time
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [136.9470, 7.3256, 191.4316, 18.4601, 121.1504]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Decryption Time in seconds", ylabel="DECRYPTION TIME");

# Memory usage
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [84.10, 91.20, 81.50, 87.90, 84.80]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Memory Usage in percentage", ylabel="MEMORY USAGE");

# CPU Usage
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [15.60, 13.40, 12.50, 18.4601, 12.90]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="CPU Usage in percentage", ylabel="CPU USAGE");

# %%
import matplotlib.pyplot as plt

# DATASET SIZE : 113 MB

# Encryption time
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [654.6948, 14.7323, 488.8878,101.4945, 635.8234]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Encryption Time in seconds", ylabel="ENCRYPTION TIME");

# Decryption time
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [694.6948, 41.8787, 994.3997, 121.4945, 655.8234]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Decryption Time in seconds", ylabel="DECRYPTION TIME");

# Memory usage
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [80.90, 94.80, 76.30, 83.70, 79.70]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="Memory Usage in percentage", ylabel="MEMORY USAGE");

# CPU Usage
x = ['AES', 'DES', 'BLOWFISH', 'ChaCha20Poly1305', 'ECC+AES']
y = [12.90, 12.40, 13.10, 14.30, 13.20]
colors = ["#6a0dad", "#f72585", "#3a0ca3", '#f72585', "#6a0dad"]
fig, ax = plt.subplots()
plt.barh(y=range(len(x)), tick_label=x, width=y, height=0.4, color=colors);
ax.set(xlabel="CPU Usage in percentage", ylabel="CPU USAGE");

# %%
import pandas as pd
import os
import time
import psutil
from pyspark.sql import SparkSession
from pyspark.sql.functions import pandas_udf, PandasUDFType, col
from pyspark.sql.types import StructType, StructField, StringType
import base64

# Create SparkSession
spark = SparkSession.builder.appName("DatasetEncryption").getOrCreate()
# Read the CSV file
df = spark.read.csv(r"C:\Users\91974\Documents\Bitcoin_tweets.csv", header=True, inferSchema=True)
# Choose the number of partitions
partitions = 4
df = df.repartition(partitions)

# Define the Blowfish encryption function
@pandas_udf(returnType=StructType([
    StructField("key", StringType()),
    StructField("iv", StringType())
] + [
    StructField("encrypted_" + c, StringType()) for c in df.columns
]), functionType=PandasUDFType.GROUPED_MAP)
def blowfish_encrypt(df: pd.DataFrame) -> pd.DataFrame:
    from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
    from cryptography.hazmat.primitives import padding
    import base64

    key = os.urandom(32)
    iv = os.urandom(8)
    cipher = Cipher(algorithms.Blowfish(key), modes.CBC(iv))

    def pad_and_encrypt(value):
        if value is None:
            return None
        padder = padding.PKCS7(64).padder()
        padded_data = padder.update(value.encode()) + padder.finalize()
        encryptor = cipher.encryptor()
        return base64.b64encode(encryptor.update(padded_data) + encryptor.finalize()).decode()

    # Encrypt all original columns
    start_time = time.time()
    for col in df.columns:
        if not col.startswith("encrypted_") and col not in ["key", "iv"]:
            encrypted_col = "encrypted_" + col
            df[encrypted_col] = df[col].apply(lambda x: pad_and_encrypt(x))
    end_time = time.time()

    df["key"] = base64.b64encode(key).decode()
    df["iv"] = base64.b64encode(iv).decode()

    cpu_usage = psutil.cpu_percent()
    memory_usage = psutil.virtual_memory().percent

    print(f"Encryption time: {end_time - start_time:.4f} seconds")
    print(f"CPU usage: {cpu_usage:.2f}%")
    print(f"Memory usage: {memory_usage:.2f}%")

    # Return only the encrypted columns, key, and IV
    encrypted_df = df[["key", "iv"] + ["encrypted_" + c for c in df.columns if not c.startswith("encrypted_") and c not in ["key", "iv"]]]
    return encrypted_df

# Define the Blowfish decryption function to decrypt all columns
@pandas_udf(returnType=StructType([
    StructField("decrypted_" + c, StringType()) for c in df.columns
]), functionType=PandasUDFType.GROUPED_MAP)
def blowfish_decrypt(df: pd.DataFrame) -> pd.DataFrame:
    from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
    from cryptography.hazmat.primitives import padding

    # Get the Blowfish key and IV from the first row of the DataFrame
    key = base64.b64decode(df.iloc[0]["key"])  # Decode the key
    iv = base64.b64decode(df.iloc[0]["iv"])    # Decode the IV

    # Create a Blowfish cipher object with the key
    cipher = Cipher(algorithms.Blowfish(key), modes.CBC(iv))
    def unpad_and_decrypt(value):
        if value is None:
            return None
        decryptor = cipher.decryptor()
        decrypted_data = decryptor.update(base64.b64decode(value.encode())) + decryptor.finalize()
        unpadder = padding.PKCS7(64).unpadder()
        return unpadder.update(decrypted_data) + unpadder.finalize()

    for c in df.columns:
        if c.startswith("encrypted_"):
            df["decrypted_" + c.replace("encrypted_", "")] = df[c].apply(lambda x: unpad_and_decrypt(x))
    end_time = time.time()

    cpu_usage = psutil.cpu_percent()
    memory_usage = psutil.virtual_memory().percent

    print(f"Decryption time: {end_time - start_time:.4f} seconds")
    print(f"CPU usage: {cpu_usage:.2f}%")
    print(f"Memory usage: {memory_usage:.2f}%")

    # Return only the decrypted columns
    decrypted_df = df[[c for c in df.columns if c.startswith("decrypted_")]]
    return decrypted_df

# Encrypt the dataset using Blowfish
start_time = time.time()
df_encrypted = df.groupBy().apply(blowfish_encrypt)
end_time = time.time()
encryption_time = end_time - start_time
print(f"\nAverage encryption time: {encryption_time / partitions:.4f} seconds")
print(f"Overall encryption time: {encryption_time:.4f} seconds\n")
df_encrypted.show()

# Decrypt the dataset using Blowfish
start_time = time.time()
df_decrypted = df_encrypted.groupBy().apply(blowfish_decrypt)
end_time = time.time()
decryption_time = end_time - start_time
print(f"\nAverage decryption time: {decryption_time / partitions:.4f} seconds")
print(f"Overall decryption time: {decryption_time:.4f} seconds\n")
df_decrypted.show()
# Out:
# Average encryption time: 0.0147 seconds
# Overall encryption time: 0.0590 seconds
#
# +--------------------+------------+--------------------+----------------------+--------------------+--------------------------+----------------------+-----------------------------+----------------+----------------------+-----------------------+--------------------+--------------------+--------------------+----------------------+------------------------+--------------------+----------------------+
# |                 key|          iv|encrypted_product_id|encrypted_product_name|  encrypted_category|encrypted_discounted_price|encrypted_actual_price|encrypted_discount_percentage|encrypted_rating|encrypted_rating_count|encrypted_about_product|   encrypted_user_id| encrypted_user_name| encrypted_review_id|encrypted_review_title|encrypted_review_content|  encrypted_img_link|encrypted_product_link|
# +--------------------+------------+--------------------+----------------------+--------------------+--------------------------+----------------------+-----------------------------+----------------+----------------------+-----------------------+--------------------+--------------------+--------------------+----------------------+------------------------+--------------------+----------------------+
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|LChzsIoheuhWU321f...|  LbDoEBv6ZsL/8ejKP...|+FdAX/Yj93o9Frbz5...|              jxlML1BxNxo=|  P+IXUW1NqLUuqFNLB...|                 GL3v0D9SSdg=|    Lde0QvT9LuY=|          HMy8KpIgXXg=|   0FvCR0lj4n+37v3GU...|nhYLP0GYqswvTj8vd...|6RSqQxZ/olAAdBC6n...|BSQ8MjqSDduY3cF22...|  1/L8xWp+q9K+A+rdu...|    dQbajBQFSuAexm9Xh...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|oVQUatkyuwJPJ7jbu...|  4a8yaI0K+SRpxLgb8...|+FdAX/Yj93pZzRdzR...|      1PgTfRVYvG4Q0fe3Y...|  lTcGmL8LU15CPTZD8...|                 vpYz8ImNwxI=|    NIaxM8L9U6w=|          Cb/vkbEKrws=|   n2sUE4dnTg4+zEcPb...|oMYhEV4LidCnTgKzK...|NbHkFL+TFc3iAK0PI...|NMbxzRBR10tcuxBrj...|  ivsE0Nhqn6xfI4rdG...|    x4HTp+nrfGoVM9LMa...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|+g8LnormRJL+0uwbh...|  SktaVD3xq6qinzRQt...|+FdAX/Yj93pKrvPj+...|      wKdGDuZ/0QAH7WcgO...|  JaLuxq2mgElFbuxdH...|                 od3A1JYOidQ=|    zq1YW+JZCFQ=|          36123B0ABF4=|   v4Icv+k3f1tCcjWo7...|jNWs8vYVIyWzzNJLb...|Rl5F1NbXX4Gad/UZP...|y5tON4zJ5q4/AwlWw...|  CMibOPfznOM8NS4AM...|    q/4H+xZge9zJBRm2A...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|8csC7h4KBj/Z6ZfKC...|  R5nUq5dLo+Za3qgtM...|+FdAX/Yj93o9Frbz5...|      c27nw9Gnt4Fh1Wh1m...|  YGgAFHSa4jgqrmpo0...|                 VXHI/M5bRU0=|    zq1YW+JZCFQ=|          s3ZgSxWtVic=|   InLNnu3c8LIIzb0bs...|3zXUSCbd6Z91MvWRu...|82SVhAOuako9Ck66L...|0Jl9oorB8gmpGtoVp...|  IHhmGsqnpok1yCajs...|    P6VsgSmSQ7K3KFTdM...|UDMjciaqwdRYqerIu...|  VNRbr++S5W7JmDzJX...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|fRGbxNyZXTCZJvFMU...|  moKfYPUnCE98mLt8g...|8+628hYpZLoBYU6J2...|              CassgAbd0mQ=|          WDPZMsCLy1w=|                 qDRbOx9dduE=|    3lBKnI4onT0=|          LY8ffQFajF0=|   oMnjhwpljVuh4Ixhd...|f9gTtcrQKYAmnDNDE...|UEVfj51s0/ZVPnzKi...|7cSNhE+rVoYbm+rvD...|  g2qU3Ax0FtY42Y7OZ...|    err7rRrkcgPc057PC...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|h+Mm03RvbMW6kqCOw...|  anHhJFBxnN3WlFoN0...|8+628hYpZLoBYU6J2...|      69d9MRH6bkJsVPeoD...|  BW+injXuJnaoyN5Zq...|                 0OTCqThuUyo=|    /8d8R6l2syw=|          CuOXcdgoWvw=|   t34R+gYI3tAoH4+TN...|K0qqJ4kf4MhKgjpa7...|MDnI4A4h9cEHb58KA...|1saWJceyFvp8i4BzV...|  PULtiTDTsHZ5clZmO...|    XBwxYg7ZjS3jvgoBv...|GYXeOw2xx/1BWshBS...|  ZEIP6jxhJe5omG+Q5...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|ob8VAbFLrkI/BynV8...|  /zC4wJmvnB9xBLUVG...|DlugmNahLyiqt+cM7...|      oCfQ5KhKmmpdmF10H...|  8jwGor4fQ5VeyiNQ3...|                 /lqG90hlOxs=|    do/F1tAQFOM=|          EyA99Z7g0lw=|   PjuPbWhjGydFpqi9Z...|GdHUgzT/LoTlBa9S4...|kzFE6L3Szkg0oP057...|FGLIBbnQLQCdsV1C1...|  4WSvA4aIfKmf/HjLc...|    NC3+tThIuw57CLHyE...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|txT2jls9Io+s1W++8...|  yS0aP+ekMFSYkVkmj...|+FdAX/Yj93pKrvPj+...|      tRrjvC8p4zUuMKD4w...|  TWAzfd3rFxdHizH6K...|                 yPKLKTQrstc=|    NIaxM8L9U6w=|  4Q6U4QeYWCxbqb909...|   sgxYGxpmSaqUytp+5...|h6MR4k7D2sMZVGvg2...|OlH39dXYep1r1r5vc...|DaC7WR7OhRPKMOLq7...|  CkdbZSRZ38nTPjYA8...|    xgzqWNQi80M7iXAoT...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|hkyvNi3QjmuhsYgTX...|  qRzmv5WEWeig52Jrw...|DlugmNahLyjMRH6W2...|      Rqh9gb/G7cxBYdx3m...|  HzioLMm/wN3hnsS66...|                 LEhgB17VCS8=|    do/F1tAQFOM=|          3IkSQbOBWAU=|   Oub485DZXe50rRMao...|IskBW6z33nRPvk2Yb...|weLoA+E0s0K16lLt6...|dLfSQiB7wDtMp6LX4...|  R7EJ+lRQaEM8HDBbv...|    R7EJ+lRQaEM8HDBbv...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|3V27nTZ+ctnPA+6Du...|  cQI+TXomPaMKRpTOI...|DlugmNahLyiqt+cM7...|      k+hX3WRDGTMxGKIqD...|  FJIKMOXkaKy70kBCa...|                 0BVH+N6Rh2U=|    NIaxM8L9U6w=|          3pQHCkb/clQ=|   ttDgGcQ74XAnLsIRs...|eusKrkjurgQrDMaTq...|LjKNKnfOj34nZgVVk...|ElBZ1IqhM5FkjfRPy...|  WHmZZaqr5icP9BiWU...|    j4VuSRRALKR+P8w17...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|5Khh08SW9PQStn7+z...|  NIrCNnbqI6p30Eia6...|8+628hYpZLoBYU6J2...|              nUsRH9IotkQ=|  dK+yIvr5CIcl5KFcT...|                 LEhgB17VCS8=|    zq1YW+JZCFQ=|          ByNqiZx6p1w=|   qrQIGrJUwPR1OlM19...|towCQOy3nOBRVKJSZ...|uJvK/9mxANnyjSf/x...|1pJS98mUetnmyK7g+...|  79tojeMMIRbSlUU3+...|    79tojeMMIRb7f0eva...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|E6YSszZnHqrjYctSu...|  kym2kZzHc8ExBwj2F...|+FdAX/Yj93pZzRdzR...|      VIxtlZkHCL0tXL7Wj...|  Qe2t3MGD4hiW4vik2...|                 nrob34RvMaA=|    PyxSWnuhv0U=|          JwN6rxh/DaE=|   Bf4SpCevtlxKMZM/Z...|2x51pxe7cYVy1oos1...|x6gRzvT1lLHZBpWn/...|DLbI42lrznalpLB82...|  tQYGqDhxBrzX4x8Yx...|    1A2Jq9MQK0sDpvpyf...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|Tbo0H5REWVKhk/Imc...|  A0NaFLjFrqmFAxM25...|DlugmNahLyiqt+cM7...|              TPe3b+wT1RU=|          pmWlhddy8Sk=|                 NOmFxExyYzw=|    zq1YW+JZCFQ=|          XS207Q+xDdQ=|   IBK2uRpDPQA13tCin...|9CtsRXqXiPTHQQw9I...|1J5GN6QWPbgyzMWNF...|c+c43BoOwCb6CywiX...|  n2Y2iCHj3l7x/yf5z...|    n2Y2iCHj3l7VaPdgB...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|3+vdgMWQZm+lMrU3g...|  /QNOFNiv63X8SFo/L...|+FdAX/Yj93pZzRdzR...|      uruNT7qabe2LFwQTQ...|  S+kFYZ65F1W8IA+gZ...|                 ftE+mRIBilA=|    Lde0QvT9LuY=|          1pU0YoL800g=|   n2sUE4dnTg5Wg/zlX...|TmaNwt2tOpIfA7aYp...|MpiMTqKFs34S+YeQi...|iFVSk9AnYkgNs2IjF...|  m+YeeoUbID15r86if...|    TNVrZYhFlxcHSideN...|RVcBCzsKxtW/9vkqP...|  UM9Mlomqo9lwHHAb2...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|gvUEEA0zgUCf5lZqm...|  5LUUG9jw3an4OG4KO...|+FdAX/Yj93pZzRdzR...|      Mgdpqaob2JudKO7MN...|  Dtl/JE4T3ZSUb1Oir...|                 kX8/rUK/aAo=|    NIaxM8L9U6w=|          f9/GDx51dzg=|   n2sUE4dnTg5Wg/zlX...|38kHGGLAAdsQw6QBN...|eh9vgY69kd3d34jTr...|qg0JWMe/3IwL0rHek...|  EUqiu0pWopX/z7oVA...|    kNQf/mrqE06aNbSIq...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|VBTNe1QfRbRKqjtBO...|  3KpesBGy+dRYC/7CV...|DlugmNahLyjMRH6W2...|      Jfu5bp0HkXfU8kBpi...|  olH7Tvx9p/ji2wS/v...|                 kXTj6Zvk7ao=|    /8d8R6l2syw=|          6VQo5Hstkp8=|   sl7VYW9WS3cufl4PC...|PzWxAo/0cLfovEvwS...|1J5GN6QWPbgyzMWNF...|MWkPVwOnjfC4rUaI2...|  fMdK3RAuY1p9/K2GH...|    7KjzwybeMJ4ZDxsFC...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|W7Bf/e/TU8iLctYDt...|  +UKQuJp2slGpUSKXx...|8+628hYpZLoBYU6J2...|      Zn3IRhGtdN4BjRYhQ...|  CHEeHGrc7UQbSQvFa...|                 od3A1JYOidQ=|    NIaxM8L9U6w=|          b4ete/mUWKg=|   6CsCauClwwwD026iU...|xmvOJLPv98xJcLYFX...|Y4j2VwuVyNqP+Aei4...|ee7w4yGQEHWC6vVoo...|  d6GHJPR/VCEUivK/h...|    F55NXVnsZ2jsiBegj...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|XGWTFAr/liiiad/z3...|  /7jrxeqgEI001/59S...|+FdAX/Yj93pZzRdzR...|      x+k6LaSEBi66SkmrC...|  myPINMOWdOk2zjvEF...|                 PQkuVczQTFs=|    Lde0QvT9LuY=|          qjKWKcMcPJE=|   n2sUE4dnTg6Od30Bf...|TmaNwt2tOpIfA7aYp...|MpiMTqKFs34S+YeQi...|iFVSk9AnYkgNs2IjF...|  m+YeeoUbID15r86if...|    TNVrZYhFlxcHSideN...|RVcBCzsKxtW/9vkqP...|  UM9Mlomqo9lwHHAb2...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|K7/hVVLRDTOjNQlaD...|  e0YMkn20uzEoj7p8m...|8+628hYpZLoBYU6J2...|              mhuscpBEwAQ=|          sUm5vXLj83Y=|                 7LvvqFkASUI=|    yug0eom4/NU=|          Fm/44qCUbiI=|   ueBd2zYpBAcLJYr/s...|j9oWF9f6B5Es9MJ5z...|U/4SAtzwigq3uObVQ...|xwVL2YO0DJfcf7EmG...|  fJAdBHpOI5t+UCH4t...|    nV+ibFQrJqcZu/Asg...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# |nKJLFKS7z/c278zBi...|vVBNBaX8l9w=|EyTyVL3dZsc1F+Cfb...|  vzRUPxb2sQl/UtwNT...|DlugmNahLyiqt+cM7...|      QenPx3aoDxwqvcahg...|  tHTJ/JKmC5t06AVaY...|                 qLYuK+WHdOU=|    do/F1tAQFOM=|          4DTjFrVYG9U=|   IpSo8ULa+Rf1Z3oE0...|0evrSFkv2DkgkeYrF...|a7/sb205fDFciX4On...|vP39rRDxTwCrAljmf...|  fMdK3RAuY1p9/K2GH...|    dNFTZ4nS60HovPq8S...|x7dSxDVfkR2fZmz1A...|  x7dSxDVfkR2oWUSML...|
# +--------------------+------------+--------------------+----------------------+--------------------+--------------------------+----------------------+-----------------------------+----------------+----------------------+-----------------------+--------------------+--------------------+--------------------+----------------------+------------------------+--------------------+----------------------+
# only showing top 20 rows
#
#
# Average decryption time: 0.0201 seconds
# Overall decryption time: 0.0805 seconds
# +--------------------+----------------------+--------------------+--------------------------+----------------------+-----------------------------+----------------+----------------------+-----------------------+--------------------+--------------------+--------------------+----------------------+------------------------+--------------------+----------------------+
# |decrypted_product_id|decrypted_product_name|  decrypted_category|decrypted_discounted_price|decrypted_actual_price|decrypted_discount_percentage|decrypted_rating|decrypted_rating_count|decrypted_about_product|   decrypted_user_id| decrypted_user_name| decrypted_review_id|decrypted_review_title|decrypted_review_content|  decrypted_img_link|decrypted_product_link|
# +--------------------+----------------------+--------------------+--------------------------+----------------------+-----------------------------+----------------+----------------------+-----------------------+--------------------+--------------------+--------------------+----------------------+------------------------+--------------------+----------------------+
# |          B08MTLLSL8|  boAt Bassheads 10...|Electronics|Headp...|                      ₹399|                ₹1,290|                          69%|             4.2|                76,042|   Let go off all yo...|AHQWVH4J5YCLOZJMQ...|SUPER HEAT,Vicky ...|R1V27KSTIYDLNO,RO...|  Sound and Bass,It...|    The Sound quality...|https://m.media-a...|  https://www.amazo...|
# |          B0B1YY6JJL|  Acer 109 cm (43 i...|Electronics|HomeT...|                   ₹23,999|               ₹34,990|                          31%|             4.3|                 4,703|   Resolution : 4K U...|AFSMISGEYDYIP3Z42...|Ayush,ROHIT A.,Ke...|R1EBS3566VCSCG,R2...|  Wonderful TV and ...|    About the TV - Wo...|https://m.media-a...|  https://www.amazo...|
# |          B09LHYZ3GJ|  Redmi Note 11T 5G...|Electronics|Mobil...|                   ₹16,999|               ₹20,999|                          19%|             4.1|                31,822|   Processor: MediaT...|AGD5KTBDTS26I2SB3...|Kapil kumar,Rajen...|R1A2H4LNTTSZKN,R2...|  Good 5g mobile,Ov...|    Good one display ...|https://m.media-a...|  https://www.amazo...|
# |          B07XJWTYM2|  realme Buds Wirel...|Electronics|Headp...|                    ₹1,679|                ₹1,999|                          16%|             4.1|                72,563|   11.2 mm bass boos...|AEHC7ITQUJKLOGQJC...|Tech boy,Deepak,8...|R1AKJKNRBIBCV4,R2...|  Original review ?...|    "(Realme Buds Wir...| it's not like th...|   surely you can l...|
# |          B098NS6PVG|  Ambrane Unbreakab...|Computers&Accesso...|                      ₹199|                  ₹349|                          43%|             4.0|                43,994|   Compatible with a...|AECPFYFQVRUWC3KGN...|ArdKn,Nirbhay kum...|RGIQEG07R9HS2,R1S...|  A Good Braided Ca...|    I ordered this ca...|https://m.media-a...|  https://www.amazo...|
# |          B09TMZ1MF8|  Western Digital W...|Computers&Accesso...|                    ₹1,709|                ₹4,000|                          57%|             4.4|                 3,029|   "SLC (single-leve...| downloadable Wes...|AEKGNCGEX4A2YHHJV...|SHAHID SHAIKH,Ama...|  R1EFJNZ479B858,R2...|    WD not interrupt,...|"WD only names EN...|   tell to anybody ...|
# |          B00NW4UWN6|  Prestige PKGSS 1....|Home&Kitchen|Kitc...|                    ₹1,043|                ₹1,345|                          22%|             3.8|                15,592|   Content: Prestige...|AGQPAKYDQNK56M5SR...|Vikash Kumar,PD,A...|R2OV4KZZ6XRELD,R2...|  Recommended but n...|    This review is af...|https://m.media-a...|  https://www.amazo...|
# |          B08HV83HL3|  MI Power Bank 3i ...|Electronics|Mobil...|                    ₹2,049|                ₹2,199|                           7%|             4.3|              1,78,912|   20000mAh Lithium ...|AG3SQH676VN5EH4ND...|Mahesh Paryani,Te...|R31BXRU0GAOB26,R1...|  Ok product to buy...|    I haven’t used an...|https://m.media-a...|  https://www.amazo...|
# |          B07W4HTS8Q|  ACTIVA Instant 3 ...|Home&Kitchen|Heat...|                    ₹1,899|                ₹3,790|                          50%|             3.8|                 3,842|   Manufactured unde...|AH4ZZLZF5JO74MJ3E...|Gajendra Kumar sh...|R371P01X49V8QV,R3...|  Value for money,G...|    Value for money,L...|https://m.media-a...|  https://www.amazo...|
# |          B008QTK47Q|  Philips GC1905 14...|Home&Kitchen|Kitc...|                    ₹1,614|                ₹1,745|                           8%|             4.3|                37,974|   To Prevent Water ...|AF7IXQKBUL6NEIQG4...|Neeraj Vishwakarm...|R15OH35Q9GBPXD,R1...|  How to choose an ...|    Update as on 28.1...|https://m.media-a...|  https://www.amazo...|
# |          B0085IATT6|  D-Link DIR-615 Wi...|Computers&Accesso...|                      ₹899|                ₹1,800|                          50%|             4.1|                22,375|   N 300 Mbps wirele...|AGMK2IKWHYVHPTNZZ...|Omm....,Cyril Geo...|R2YMRG3A0V8G85,R2...|  Very good,It does...|    Very good connect...|https://m.media-a...|  https://www.amazo...|
# |          B097JVLW3L|  Irusu Play VR Plu...|Electronics|HomeT...|                    ₹2,699|                ₹3,500|                          23%|             3.5|                   621|   ✔️40MM HD optical...|AF3KXMJ35ELNULRGL...|Wasim Mulla,PrItH...|R2RS5DJTMPR9KH,R3...|  Really great devi...|    The product is ov...|https://m.media-a...|  https://www.amazo...|
# |          B00PVT30YI|  Kitchen Mart Stai...|Home&Kitchen|Kitc...|                      ₹292|                  ₹499|                          41%|             4.1|                 4,238|   Material: Food Gr...|AFUYYV4MJWXM6FKQL...|Amazon Customer,m...|R2UUBE6SD6DQ9Y,RY...|  Coffee Filter,Jus...|    Coffee Filter is ...|https://m.media-a...|  https://www.amazo...|
# |          B08Y55LPBF|  Redmi 126 cm (50 ...|Electronics|HomeT...|                   ₹32,999|               ₹44,999|                          27%|             4.2|                45,238|   Resolution: 4K Ul...|AG6WSLLXZY52HSQUY...|prateeq,Suraj Cha...|R3CR9H6ABJ4Q4O,R2...|  "Worth the price,...|    Worth using since...| expect more from mi|      Worth for money.|
# |          B0B3XXSB1K|  LG 139 cm (55 inc...|Electronics|HomeT...|                   ₹47,990|               ₹79,990|                          40%|             4.3|                 1,376|   Resolution: 4K Ul...|AFCWL3MX7BP2ZUDD3...|Raj Mohammed,Sams...|RC3ZLDRM8GA9T,RMD...|  Love Amazon but l...|    There's no magic ...|https://m.media-a...|  https://www.amazo...|
# |          B08GM5S4CQ|  Havells Instanio ...|Home&Kitchen|Heat...|                    ₹6,990|               ₹14,290|                          51%|             4.4|                 1,771|   Suitable for high...|AGUM6DLWGQ2LOM4MC...|Amazon Customer,G...|R3N1KWPD82KCJH,RU...|  Good product but ...|    For this price ra...|https://m.media-a...|  https://www.amazo...|
# |          B07BRKK9JQ|  Zebronics Zeb-Tra...|Computers&Accesso...|                    ₹1,299|                ₹1,599|                          19%|             4.3|                27,223|   Multicolor LED ( ...|AHEPPTU7YZ4YNMCKF...|Kshanik Rajak,Gaj...|R1WLR0EBTL2IX6,R2...|  Click-Bet,The alp...|    Always wanted to ...|https://m.media-a...|  https://www.amazo...|
# |          B09F9YQQ7B|  Redmi 80 cm (32 i...|Electronics|HomeT...|                   ₹13,999|               ₹24,999|                          44%|             4.2|                45,237|   Resolution: HD Re...|AG6WSLLXZY52HSQUY...|prateeq,Suraj Cha...|R3CR9H6ABJ4Q4O,R2...|  "Worth the price,...|    Worth using since...| expect more from mi|      Worth for money.|
# |          B0994GP1CX|  "LS LAPSTER Quali...|Computers&Accesso...|                      ₹115|                  ₹999|                          88%|             3.3|                 5,692|   -Easy to attach, ...|AFW5XNPYWYUD54B4G...|Dinesh jumani,HIR...|R26Z6SSJJ8MDIO,R1...|  Quality,It's not ...|    Fine product not ...|https://m.media-a...|  https://www.amazo...|
# |          B07WVQG8WZ|  Black+Decker Hand...|Home&Kitchen|Kitc...|                    ₹3,299|                ₹4,995|                          34%|             3.8|                 1,393|   On/Off and adjust...|AFXYPYAOFDHWH4CXS...|Nadeem,Viral,anki...|R11V5OCJYQY6WC,RI...|  Good product but ...|    Quality product b...|https://m.media-a...|  https://www.amazo...|
# +--------------------+----------------------+--------------------+--------------------------+----------------------+-----------------------------+----------------+----------------------+-----------------------+--------------------+--------------------+--------------------+----------------------+------------------------+--------------------+----------------------+
# only showing top 20 rows
